# %%
import os
import cv2
import numpy as np
from pathlib import Path
import h5py
import matplotlib.pyplot as plt
from tensorflow.keras.layers import InputLayer, Reshape, Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from sklearn.metrics import  confusion_matrix,precision_score,accuracy_score,recall_score,ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Nadam
import pandas as pd
import face_recognition

# %%
URL="./Videos"

# %%
metricas={"precision":[],"recall":[]}

# %% [markdown]
# ## Funciones definidas

# %%
def obtenerDatos(archivo):
   data=h5py.File(archivo)
   return data["X"][:],data["Y"][:]

# %%
def obtener_etiquetas(url):
    labels=[]
    for index,carpeta in enumerate(os.listdir(str(url))):
        labels.append(carpeta)
    return labels

# %%
def normalizar(X):
    return (X- X.min()) / (X.max() - X.min())

# %%
def redimensionarData(X,ancho,largo):
    imagenes=[]
    for imagen in X:
        imagenes.append(cv2.resize(imagen, (ancho, largo), interpolation=cv2.INTER_AREA))
    return np.array(imagenes)

# %%
def redimensionarDataYVolverRGB(X,ancho,largo):
    imagenes=[]
    for imagen in X:
        imagenes.append(cv2.cvtColor(cv2.resize(imagen, (ancho, largo), interpolation=cv2.INTER_AREA),cv2.COLOR_BGR2RGB))
    return np.array(imagenes)

# %%
def graficarHistorialEntrenamiento(historial):
    plt.plot(historial.history["loss"],label="costo")
    plt.plot(historial.history["val_loss"],label="costo_data_val")
    plt.plot(historial.history["accuracy"],label="precision")
    plt.plot(historial.history["val_accuracy"],label="precision_data_val")
    plt.xlabel("Epoca")
    plt.legend()
    plt.title('Evolución de la pérdida en el entrenamiento')
    plt.show()

# %%
def graficarMatrizDeConfusion(y_test,y_pred,labels):
    modeloCM=confusion_matrix(y_test,y_pred)
    cm=ConfusionMatrixDisplay(modeloCM,display_labels=labels)
    cm.plot()

# %%
def get_metricasModelo(df,y_test,y_pred):
    precision=precision_score(y_test,y_pred,average="macro")
    recall=recall_score(y_test,y_pred,average="macro")
    df["precision"].append(precision)
    df["recall"].append(recall)
    return df

# %%
def calculate_face_recognize(image, model="hog"):
    """
    Calcula el encoding de un rostro en una imagen.
    
    Args:
    - image: La imagen de entrada (matriz numpy).
    - model: Modelo a usar para detección de rostros ("hog" o "cnn").
    
    Returns:
    - Un vector de 128 dimensiones (encoding del rostro) si se detecta un rostro.
    - Un vector de ceros si no se detecta ningún rostro.
    """
    # Detectar ubicaciones de rostros
    face_locations = face_recognition.face_locations(image, model=model)
    
    # Calcular encodings
    encodings = face_recognition.face_encodings(image, face_locations)
    
    # Si no se detectan rostros, retorna un vector de ceros
    if len(encodings) == 0:
        return np.zeros(128)
    
    # Retorna el encoding del primer rostro detectado
    return encodings[0]

"""
HOG:

Convierte la imagen a escala de grises internamente.
Calcula características basadas en gradientes y patrones, independientemente de la escala o el brillo de la imagen.
CNN:

Trabaja directamente con imágenes RGB.
A través de sus capas convolucionales, extrae características y realiza ajustes de escala automáticamente.
"""
# Out:
# '\nHOG:\n\nConvierte la imagen a escala de grises internamente.\nCalcula características basadas en gradientes y patrones, independientemente de la escala o el brillo de la imagen.\nCNN:\n\nTrabaja directamente con imágenes RGB.\nA través de sus capas convolucionales, extrae características y realiza ajustes de escala automáticamente.\n'

# %%
def plot_image(image):
    plt.imshow(image, cmap = "gray", interpolation = "nearest")
    plt.axis("off")

## Cargamos los datos

# %%
X_train,y_train=obtenerDatos("./data/datos_train_color.h5")

# %%
X_test,y_test=obtenerDatos("./data/datos_test_color.h5")

# %%
X_train.shape
# Out:
# (2400, 200, 200, 3)

# %%
y_train.shape
# Out:
# (2400,)

# %%
X_test.shape
# Out:
# (800, 200, 200, 3)

# %%
y_test.shape
# Out:
# (800,)

# %% [markdown]
# ## Visualizamos la data

# %%
plt.imshow(X_train[2000])

# %%
plt.imshow(X_train[500])

# %%
labels=[]

# %%
labels=obtener_etiquetas(URL)
labels
# Out:
# ['Agus', 'Ale', 'Noni', 'Sebas']

# %%
X_train_copia=X_train.copy()
X_test_copia=X_test.copy()

# %%
y_train_copia=y_train.copy()
y_test_copia=y_test.copy()

# %%
X_train_copia=redimensionarData(X_train_copia,160,160)
X_test_copia=redimensionarData(X_test_copia,160,160)

X_train_copia = np.array([
    calculate_face_recognize(img,model="hog")
    for img in X_train_copia
])

X_test_copia = np.array([
    calculate_face_recognize(img,model="hog")
    for img in X_test_copia
])

X_train_copia=normalizar(X_train_copia)
X_test_copia=normalizar(X_test_copia)

# %%
X_train_copia.shape
# Out:
# (2400, 128)

# %%
X_test_copia.shape
# Out:
# (800, 128)

# %%
class ModeloPersonalizado:
    def __init__(self, input_dim, output_dim):
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.modelo = None
        self.historial = None
        self.predicciones = None
        self.matriz_confusion = None

    def construir_modelo(self, configuracion):
        self.modelo = Sequential()
        self.modelo.add(InputLayer(input_shape=(self.input_dim,)))

        for capa in configuracion["capas_ocultas"]:
            self.modelo.add(Dense(capa["neuronas"], activation=capa["activation"]))
            if "dropout" in capa and capa["dropout"] > 0:
                self.modelo.add(Dropout(capa["dropout"]))

        self.modelo.add(Dense(self.output_dim, activation="softmax"))

    def compilar_modelo(self, learning_rate):
        optimizer = Nadam(learning_rate=learning_rate)
        self.modelo.compile(
            optimizer=optimizer,
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"]
        )

    def entrenar_modelo(self, X_train, y_train, X_val, y_val, epochs, factor_reduccion, paciencia):
        """
        Un callback en Keras es un conjunto de funciones que puedes usar para personalizar y controlar el proceso de entrenamiento del modelo
        ReduceLROnPlateau es un callback en Keras que se utiliza para reducir la tasa de aprendizaje (learning rate)
        automáticamente si una métrica(val_loss) no mejora después de un número definido de épocas (patience).
        min_lr:El learning rate no se reducirá por debajo de este valor, lo que previene que se acerque a cero.
        lr_scheduler=planificador de la tasa de aprendizaje

        Todo este trabajo se hace poruqe la tasa de aprendizaje se encarga de enontrar el j mas pequeno para los thetas
        si este j o en nuestro caso el val_loss ya no baja mucho o de la nada se subio su valor que posiblemente estemos cerca al mejor
        j o val_loss posible para los tethas y nos conviende dar pasitos mas cortos en la tasa de aprendizaje cuidando de que no sea cero con 
        min_lr
        """
        lr_scheduler = ReduceLROnPlateau(
            monitor="val_loss",
            factor=factor_reduccion,
            patience=paciencia,
            verbose=1,
            min_lr=1e-6
        )

        self.historial = self.modelo.fit(
            X_train, 
            y_train, 
            epochs=epochs, 
            validation_data=(X_val, y_val), 
            callbacks=[lr_scheduler], 
            verbose=1
        )

    def evaluar_modelo(self, X_test, y_test, labels, configuracion):
        probabilidades = self.modelo.predict(X_test)
        self.predicciones = np.argmax(probabilidades, axis=1)

        #El macro average calcula la precisión y el recall de forma independiente para cada clase. Luego toma el promedio aritmético de esas métricas.
        precision = precision_score(y_test, self.predicciones, average="macro")
        recall = recall_score(y_test, self.predicciones, average="macro")

        self.matriz_confusion = confusion_matrix(y_test, self.predicciones)

        resultados = {
            "configuracion": configuracion,
            "precision": precision,
            "recall": recall,
            "historial": self.historial.history,
            "matriz_confusion": self.matriz_confusion
        }

        return resultados

# %%
configuraciones = [
    # Etapa 1: 
    {
        "capas_ocultas": [{"neuronas": 32, "activation": "relu", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 32, "activation": "tanh", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 32, "activation": "leaky_relu", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 32, "activation": "swish", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 64, "activation": "relu", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 64, "activation": "tanh", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 64, "activation": "leaky_relu", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 64, "activation": "swish", "dropout": 0.1}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 128, "activation": "relu", "dropout": 0.2}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 128, "activation": "tanh", "dropout": 0.2}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 128, "activation": "leaky_relu", "dropout": 0.2}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [{"neuronas": 128, "activation": "swish", "dropout": 0.2}],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    
    # Etapa 2: 
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "relu", "dropout": 0.2},
            {"neuronas": 64, "activation": "relu", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "leaky_relu", "dropout": 0.2},
            {"neuronas": 64, "activation": "leaky_relu", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "swish", "dropout": 0.2},
            {"neuronas": 64, "activation": "swish", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "relu", "dropout": 0.2},
            {"neuronas": 32, "activation": "relu", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "leaky_relu", "dropout": 0.2},
            {"neuronas": 32, "activation": "leaky_relu", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "swish", "dropout": 0.2},
            {"neuronas": 32, "activation": "swish", "dropout": 0.2},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },

    # Etapa 3: 
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "relu", "dropout": 0.2},
            {"neuronas": 64, "activation": "relu", "dropout": 0.15},
            {"neuronas": 32, "activation": "relu", "dropout": 0.1},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "leaky_relu", "dropout": 0.2},
            {"neuronas": 64, "activation": "leaky_relu", "dropout": 0.15},
            {"neuronas": 32, "activation": "leaky_relu", "dropout": 0.1},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 128, "activation": "swish", "dropout": 0.2},
            {"neuronas": 64, "activation": "swish", "dropout": 0.15},
            {"neuronas": 32, "activation": "swish", "dropout": 0.1},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "relu", "dropout": 0.15},
            {"neuronas": 32, "activation": "relu", "dropout": 0.1},
            {"neuronas": 16, "activation": "relu", "dropout": 0.05},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "leaky_relu", "dropout": 0.15},
            {"neuronas": 32, "activation": "leaky_relu", "dropout": 0.1},
            {"neuronas": 16, "activation": "leaky_relu", "dropout": 0.05},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    },
    {
        "capas_ocultas": [
            {"neuronas": 64, "activation": "swish", "dropout": 0.15},
            {"neuronas": 32, "activation": "swish", "dropout": 0.1},
            {"neuronas": 16, "activation": "swish", "dropout": 0.05},
        ],
        "learning_rate": 0.001,
        "factor_reduccion": 0.1,
        "output": {"neuronas": 4, "activation": "softmax"},
    }
]

resultados_metricas = []

for idx, config in enumerate(configuraciones):
    print(f"Entrenando modelo {idx + 1}/{len(configuraciones)}...")

    modelo = ModeloPersonalizado(input_dim=128, output_dim=4)
    modelo.construir_modelo(config)
    modelo.compilar_modelo(learning_rate=config["learning_rate"])
    modelo.entrenar_modelo(
        X_train=X_train_copia,
        y_train=y_train,
        X_val=X_test_copia,
        y_val=y_test,
        epochs=50,
        factor_reduccion=config["factor_reduccion"],
        paciencia=5,
    )
    
    resultados = modelo.evaluar_modelo(
        X_test=X_test_copia,
        y_test=y_test,
        labels=labels,
        configuracion=config
    )
    resultados_metricas.append(resultados)

    print(f"Modelo {idx + 1} se acabo de entrenar y se guardo")

df_resultados = pd.DataFrame(resultados_metricas)
# Out:
# Entrenando modelo 1/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2967 - loss: 1.4154 - val_accuracy: 0.6538 - val_loss: 1.3250 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4936 - loss: 1.3062 - val_accuracy: 0.3150 - val_loss: 1.2720 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5474 - loss: 1.2055 - val_accuracy: 0.5275 - val_loss: 1.2210 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5672 - loss: 1.1179 - val_accuracy: 0.4100 - val_loss: 1.1717 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6432 - loss: 1.0234 - val_accuracy: 0.5913 - val_loss: 1.1003 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6843 - loss: 0.9399 - val_accuracy: 0.5725 - val_loss: 1.0418 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7016 - loss: 0.8715 - val_accuracy: 0.4650 - val_loss: 1.0029 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7098 - loss: 0.8153 - val_accuracy: 0.7450 - val_loss: 0.9415 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7611 - loss: 0.7583 - val_accuracy: 0.7638 - val_loss: 0.8936 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7450 - loss: 0.7231 - val_accuracy: 0.7625 - val_loss: 0.8496 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7839 - loss: 0.6721 - val_accuracy: 0.7638 - val_loss: 0.8042 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7751 - loss: 0.6655 - val_accuracy: 0.7487 - val_loss: 0.7822 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7871 - loss: 0.6030 - val_accuracy: 0.7638 - val_loss: 0.7577 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7689 - loss: 0.6021 - val_accuracy: 0.7638 - val_loss: 0.7225 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7765 - loss: 0.4728 - val_accuracy: 0.7638 - val_loss: 0.5551 - learning_rate: 1.0000e-04
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7866 - loss: 0.4620 - val_accuracy: 0.7638 - val_loss: 0.5556 - learning_rate: 1.0000e-04
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7907 - loss: 0.4489 - val_accuracy: 0.7638 - val_loss: 0.5553 - learning_rate: 1.0000e-04
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7980 - loss: 0.4423 - val_accuracy: 0.7638 - val_loss: 0.5530 - learning_rate: 1.0000e-04
# Epoch 48/50
# 54/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7763 - loss: 0.4620
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7795 - loss: 0.4578 - val_accuracy: 0.7638 - val_loss: 0.5572 - learning_rate: 1.0000e-04
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7855 - loss: 0.4511 - val_accuracy: 0.7638 - val_loss: 0.5565 - learning_rate: 1.0000e-05
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7861 - loss: 0.4603 - val_accuracy: 0.7638 - val_loss: 0.5557 - learning_rate: 1.0000e-05
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Modelo 1 se acabo de entrenar y se guardo
# Entrenando modelo 2/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3442 - loss: 1.3474 - val_accuracy: 0.4412 - val_loss: 1.3025 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5765 - loss: 1.1613 - val_accuracy: 0.4487 - val_loss: 1.2540 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6020 - loss: 1.0323 - val_accuracy: 0.4487 - val_loss: 1.1656 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6687 - loss: 0.9311 - val_accuracy: 0.4725 - val_loss: 1.0757 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7658 - loss: 0.8478 - val_accuracy: 0.6925 - val_loss: 1.0057 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7669 - loss: 0.7532 - val_accuracy: 0.7275 - val_loss: 0.9349 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7897 - loss: 0.6813 - val_accuracy: 0.7400 - val_loss: 0.8810 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7910 - loss: 0.6270 - val_accuracy: 0.7613 - val_loss: 0.8113 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8035 - loss: 0.5848 - val_accuracy: 0.7475 - val_loss: 0.7781 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8049 - loss: 0.5589 - val_accuracy: 0.7487 - val_loss: 0.7320 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7802 - loss: 0.5269 - val_accuracy: 0.7638 - val_loss: 0.7023 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8016 - loss: 0.5060 - val_accuracy: 0.7613 - val_loss: 0.6930 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7915 - loss: 0.5069 - val_accuracy: 0.7462 - val_loss: 0.6755 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7832 - loss: 0.4961 - val_accuracy: 0.7638 - val_loss: 0.6608 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7983 - loss: 0.4869 - val_accuracy: 0.7613 - val_loss: 0.6471 - learning_rate: 0.0010
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7896 - loss: 0.4859 - val_accuracy: 0.7487 - val_loss: 0.6473 - learning_rate: 0.0010
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7857 - loss: 0.4940 - val_accuracy: 0.7487 - val_loss: 0.6277 - learning_rate: 0.0010
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7963 - loss: 0.4745 - val_accuracy: 0.7613 - val_loss: 0.6261 - learning_rate: 0.0010
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7858 - loss: 0.4539 - val_accuracy: 0.7487 - val_loss: 0.6175 - learning_rate: 0.0010
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8013 - loss: 0.4504 - val_accuracy: 0.7638 - val_loss: 0.6092 - learning_rate: 0.0010
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7928 - loss: 0.4215 - val_accuracy: 0.7638 - val_loss: 0.5758 - learning_rate: 1.0000e-06
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8069 - loss: 0.4230 - val_accuracy: 0.7638 - val_loss: 0.5757 - learning_rate: 1.0000e-06
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8001 - loss: 0.4283 - val_accuracy: 0.7638 - val_loss: 0.5756 - learning_rate: 1.0000e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Modelo 2 se acabo de entrenar y se guardo
# Entrenando modelo 3/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3195 - loss: 1.3589 - val_accuracy: 0.3013 - val_loss: 1.3486 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4830 - loss: 1.2280 - val_accuracy: 0.4675 - val_loss: 1.3076 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5546 - loss: 1.1379 - val_accuracy: 0.4162 - val_loss: 1.2407 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6104 - loss: 1.0073 - val_accuracy: 0.5275 - val_loss: 1.1347 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7119 - loss: 0.9031 - val_accuracy: 0.5950 - val_loss: 1.0381 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7633 - loss: 0.8087 - val_accuracy: 0.6612 - val_loss: 0.9605 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7768 - loss: 0.7438 - val_accuracy: 0.6900 - val_loss: 0.9090 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7723 - loss: 0.6668 - val_accuracy: 0.7075 - val_loss: 0.8483 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7885 - loss: 0.6189 - val_accuracy: 0.7475 - val_loss: 0.7877 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7867 - loss: 0.5571 - val_accuracy: 0.7625 - val_loss: 0.7546 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.5723 - val_accuracy: 0.7500 - val_loss: 0.7149 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7622 - loss: 0.5435 - val_accuracy: 0.7638 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8054 - loss: 0.4811 - val_accuracy: 0.7638 - val_loss: 0.6497 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7856 - loss: 0.5051 - val_accuracy: 0.7600 - val_loss: 0.6535 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7975 - loss: 0.4687 - val_accuracy: 0.7638 - val_loss: 0.6828 - learning_rate: 0.0010
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.4747 - val_accuracy: 0.7638 - val_loss: 0.6172 - learning_rate: 0.0010
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.4647 - val_accuracy: 0.7638 - val_loss: 0.5956 - learning_rate: 0.0010
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7888 - loss: 0.4722 - val_accuracy: 0.7487 - val_loss: 0.6299 - learning_rate: 0.0010
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7784 - loss: 0.4588 - val_accuracy: 0.7638 - val_loss: 0.5919 - learning_rate: 0.0010
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.4376 - val_accuracy: 0.7625 - val_loss: 0.5930 - learning_rate: 0.0010
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4489 - val_accuracy: 0.7638 - val_loss: 0.5690 - learning_rate: 0.0010
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7837 - loss: 0.4726 - val_accuracy: 0.7638 - val_loss: 0.5990 - learning_rate: 0.0010
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7911 - loss: 0.4480 - val_accuracy: 0.7638 - val_loss: 0.5816 - learning_rate: 0.0010
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7772 - loss: 0.4614 - val_accuracy: 0.7638 - val_loss: 0.5952 - learning_rate: 0.0010
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7908 - loss: 0.4464 - val_accuracy: 0.7638 - val_loss: 0.5842 - learning_rate: 0.0010
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8076 - loss: 0.4143 - val_accuracy: 0.7487 - val_loss: 0.5529 - learning_rate: 0.0010
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7697 - loss: 0.4524 - val_accuracy: 0.7638 - val_loss: 0.5813 - learning_rate: 0.0010
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7744 - loss: 0.4446 - val_accuracy: 0.7638 - val_loss: 0.5571 - learning_rate: 0.0010
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7860 - loss: 0.4399 - val_accuracy: 0.7638 - val_loss: 0.5536 - learning_rate: 0.0010
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7947 - loss: 0.4085 - val_accuracy: 0.7638 - val_loss: 0.5421 - learning_rate: 0.0010
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7802 - loss: 0.4632 - val_accuracy: 0.7638 - val_loss: 0.5641 - learning_rate: 0.0010
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7755 - loss: 0.4481 - val_accuracy: 0.7487 - val_loss: 0.5565 - learning_rate: 0.0010
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7968 - loss: 0.4367 - val_accuracy: 0.7487 - val_loss: 0.5630 - learning_rate: 0.0010
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7654 - loss: 0.4512 - val_accuracy: 0.7638 - val_loss: 0.5697 - learning_rate: 0.0010
# Epoch 35/50
# 51/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7789 - loss: 0.4453
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7828 - loss: 0.4435 - val_accuracy: 0.7625 - val_loss: 0.5505 - learning_rate: 0.0010
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7848 - loss: 0.4404 - val_accuracy: 0.7638 - val_loss: 0.5480 - learning_rate: 1.0000e-04
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7975 - loss: 0.4383 - val_accuracy: 0.7638 - val_loss: 0.5456 - learning_rate: 1.0000e-04
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7986 - loss: 0.4226 - val_accuracy: 0.7638 - val_loss: 0.5470 - learning_rate: 1.0000e-04
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7969 - loss: 0.4177 - val_accuracy: 0.7638 - val_loss: 0.5461 - learning_rate: 1.0000e-04
# Epoch 40/50
# 46/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7823 - loss: 0.4471
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7839 - loss: 0.4450 - val_accuracy: 0.7638 - val_loss: 0.5477 - learning_rate: 1.0000e-04
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8116 - loss: 0.4034 - val_accuracy: 0.7638 - val_loss: 0.5481 - learning_rate: 1.0000e-05
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7808 - loss: 0.4468 - val_accuracy: 0.7638 - val_loss: 0.5481 - learning_rate: 1.0000e-05
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7776 - loss: 0.4401 - val_accuracy: 0.7638 - val_loss: 0.5478 - learning_rate: 1.0000e-05
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8074 - loss: 0.4292 - val_accuracy: 0.7638 - val_loss: 0.5481 - learning_rate: 1.0000e-05
# Epoch 45/50
# 53/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8091 - loss: 0.4095
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8047 - loss: 0.4151 - val_accuracy: 0.7638 - val_loss: 0.5479 - learning_rate: 1.0000e-05
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7748 - loss: 0.4563 - val_accuracy: 0.7638 - val_loss: 0.5479 - learning_rate: 1.0000e-06
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8037 - loss: 0.4089 - val_accuracy: 0.7638 - val_loss: 0.5479 - learning_rate: 1.0000e-06
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8030 - loss: 0.4078 - val_accuracy: 0.7638 - val_loss: 0.5479 - learning_rate: 1.0000e-06
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8027 - loss: 0.4190 - val_accuracy: 0.7638 - val_loss: 0.5479 - learning_rate: 1.0000e-06
# Epoch 50/50
# 65/75 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.7901 - loss: 0.4270
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.4273 - val_accuracy: 0.7638 - val_loss: 0.5480 - learning_rate: 1.0000e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step
# Modelo 3 se acabo de entrenar y se guardo
# Entrenando modelo 4/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7833 - loss: 0.4509 - val_accuracy: 0.7487 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 38/50
# 49/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7837 - loss: 0.4489
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7838 - loss: 0.4475 - val_accuracy: 0.7638 - val_loss: 0.5779 - learning_rate: 0.0010
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7942 - loss: 0.4431 - val_accuracy: 0.7638 - val_loss: 0.5587 - learning_rate: 1.0000e-04
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7983 - loss: 0.4244 - val_accuracy: 0.7638 - val_loss: 0.5504 - learning_rate: 1.0000e-04
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7983 - loss: 0.4276 - val_accuracy: 0.7638 - val_loss: 0.5478 - learning_rate: 1.0000e-04
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8022 - loss: 0.4203 - val_accuracy: 0.7638 - val_loss: 0.5534 - learning_rate: 1.0000e-04
# Epoch 43/50
# 71/75 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.7968 - loss: 0.4256
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7968 - loss: 0.4257 - val_accuracy: 0.7638 - val_loss: 0.5557 - learning_rate: 1.0000e-04
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8013 - loss: 0.4377 - val_accuracy: 0.7638 - val_loss: 0.5550 - learning_rate: 1.0000e-05
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7898 - loss: 0.4555 - val_accuracy: 0.7638 - val_loss: 0.5542 - learning_rate: 1.0000e-05
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7901 - loss: 0.4336 - val_accuracy: 0.7638 - val_loss: 0.5532 - learning_rate: 1.0000e-05
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7859 - loss: 0.4470 - val_accuracy: 0.7638 - val_loss: 0.5527 - learning_rate: 1.0000e-05
# Epoch 48/50
# 40/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8056 - loss: 0.4290
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8007 - loss: 0.4290 - val_accuracy: 0.7638 - val_loss: 0.5527 - learning_rate: 1.0000e-05
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7906 - loss: 0.4266 - val_accuracy: 0.7638 - val_loss: 0.5527 - learning_rate: 1.0000e-06
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7851 - loss: 0.4517 - val_accuracy: 0.7638 - val_loss: 0.5526 - learning_rate: 1.0000e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step
# Modelo 5 se acabo de entrenar y se guardo
# Entrenando modelo 6/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3754 - loss: 1.3357 - val_accuracy: 0.4387 - val_loss: 1.2886 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5382 - loss: 1.1373 - val_accuracy: 0.5038 - val_loss: 1.2079 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6523 - loss: 0.9754 - val_accuracy: 0.4487 - val_loss: 1.1105 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7073 - loss: 0.8608 - val_accuracy: 0.7113 - val_loss: 0.9729 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7862 - loss: 0.7470 - val_accuracy: 0.6087 - val_loss: 0.8973 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7857 - loss: 0.6414 - val_accuracy: 0.7625 - val_loss: 0.8063 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7914 - loss: 0.6101 - val_accuracy: 0.7625 - val_loss: 0.7571 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7986 - loss: 0.5314 - val_accuracy: 0.7638 - val_loss: 0.7114 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7905 - loss: 0.5228 - val_accuracy: 0.7550 - val_loss: 0.6770 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7924 - loss: 0.5002 - val_accuracy: 0.7487 - val_loss: 0.6559 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7852 - loss: 0.4910 - val_accuracy: 0.7638 - val_loss: 0.6392 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7975 - loss: 0.4729 - val_accuracy: 0.7625 - val_loss: 0.6326 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.5026 - val_accuracy: 0.7638 - val_loss: 0.5984 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7949 - loss: 0.4490 - val_accuracy: 0.7462 - val_loss: 0.5443 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7855 - loss: 0.4471 - val_accuracy: 0.7638 - val_loss: 0.5109 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7657 - loss: 0.4656 - val_accuracy: 0.7588 - val_loss: 0.5571 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7930 - loss: 0.4408 - val_accuracy: 0.7475 - val_loss: 0.5237 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7787 - loss: 0.4295 - val_accuracy: 0.7613 - val_loss: 0.5652 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7825 - loss: 0.4593 - val_accuracy: 0.7613 - val_loss: 0.5181 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7713 - loss: 0.4333 - val_accuracy: 0.7638 - val_loss: 0.4946 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8001 - loss: 0.4222 - val_accuracy: 0.7638 - val_loss: 0.5623 - learning_rate: 0.0010
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7842 - loss: 0.4289 - val_accuracy: 0.7625 - val_loss: 0.5614 - learning_rate: 0.0010
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7786 - loss: 0.4630 - val_accuracy: 0.7625 - val_loss: 0.5244 - learning_rate: 0.0010
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.4173 - val_accuracy: 0.7638 - val_loss: 0.5010 - learning_rate: 0.0010
# Epoch 19/50
# 55/75 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.7762 - loss: 0.4431
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7769 - loss: 0.4405 - val_accuracy: 0.7625 - val_loss: 0.5274 - learning_rate: 0.0010
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8046 - loss: 0.4109 - val_accuracy: 0.7625 - val_loss: 0.5177 - learning_rate: 1.0000e-04
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7824 - loss: 0.4345 - val_accuracy: 0.7625 - val_loss: 0.5184 - learning_rate: 1.0000e-04
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8006 - loss: 0.4391 - val_accuracy: 0.7625 - val_loss: 0.5186 - learning_rate: 1.0000e-04
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7958 - loss: 0.4213 - val_accuracy: 0.7613 - val_loss: 0.5199 - learning_rate: 1.0000e-04
# Epoch 24/50
# 63/75 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.7898 - loss: 0.4243
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7890 - loss: 0.4252 - val_accuracy: 0.7625 - val_loss: 0.5172 - learning_rate: 1.0000e-04
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7962 - loss: 0.4044 - val_accuracy: 0.7625 - val_loss: 0.5167 - learning_rate: 1.0000e-05
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7862 - loss: 0.4266 - val_accuracy: 0.7625 - val_loss: 0.5165 - learning_rate: 1.0000e-05
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7747 - loss: 0.4395 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-05
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7856 - loss: 0.4245 - val_accuracy: 0.7625 - val_loss: 0.5168 - learning_rate: 1.0000e-05
# Epoch 29/50
# 52/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7956 - loss: 0.4257
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7956 - loss: 0.4249 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-05
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7876 - loss: 0.4271 - val_accuracy: 0.7625 - val_loss: 0.5171 - learning_rate: 1.0000e-06
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4463 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7991 - loss: 0.4229 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7826 - loss: 0.4356 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# Epoch 34/50
# 56/75 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.8090 - loss: 0.4022
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8036 - loss: 0.4091 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8007 - loss: 0.4057 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7769 - loss: 0.4451 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7934 - loss: 0.4259 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7948 - loss: 0.4238 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7756 - loss: 0.4427 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7743 - loss: 0.4534 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7913 - loss: 0.4215 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7840 - loss: 0.4436 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7872 - loss: 0.4421 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7979 - loss: 0.4072 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7898 - loss: 0.4292 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4108 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7910 - loss: 0.4240 - val_accuracy: 0.7625 - val_loss: 0.5168 - learning_rate: 1.0000e-06
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7909 - loss: 0.4195 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7746 - loss: 0.4390 - val_accuracy: 0.7625 - val_loss: 0.5169 - learning_rate: 1.0000e-06
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.4227 - val_accuracy: 0.7625 - val_loss: 0.5170 - learning_rate: 1.0000e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Modelo 23 se acabo de entrenar y se guardo
# Entrenando modelo 24/24...
# Epoch 1/50
# C:\Users\MSI DESKTOP\anaconda3\envs\dlib_env\lib\site-packages\keras\src\layers\core\input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.3123 - loss: 1.3626 - val_accuracy: 0.4338 - val_loss: 1.3622 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4589 - loss: 1.2117 - val_accuracy: 0.4300 - val_loss: 1.1858 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5937 - loss: 0.9285 - val_accuracy: 0.6100 - val_loss: 0.9994 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6854 - loss: 0.7552 - val_accuracy: 0.6162 - val_loss: 0.8360 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6903 - loss: 0.6927 - val_accuracy: 0.7500 - val_loss: 0.7380 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7387 - loss: 0.6136 - val_accuracy: 0.7550 - val_loss: 0.6446 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7709 - loss: 0.5356 - val_accuracy: 0.7550 - val_loss: 0.6197 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4728 - val_accuracy: 0.7487 - val_loss: 0.6021 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7600 - loss: 0.5125 - val_accuracy: 0.7638 - val_loss: 0.5485 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4481 - val_accuracy: 0.7638 - val_loss: 0.5587 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7795 - loss: 0.4579 - val_accuracy: 0.7625 - val_loss: 0.5375 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7788 - loss: 0.4681 - val_accuracy: 0.7550 - val_loss: 0.5518 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7779 - loss: 0.4479 - val_accuracy: 0.7600 - val_loss: 0.5521 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7860 - loss: 0.4433 - val_accuracy: 0.7613 - val_loss: 0.5280 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.4365 - val_accuracy: 0.7625 - val_loss: 0.5403 - learning_rate: 0.0010
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8068 - loss: 0.4223 - val_accuracy: 0.7625 - val_loss: 0.5333 - learning_rate: 0.0010
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7949 - loss: 0.4404 - val_accuracy: 0.7638 - val_loss: 0.5182 - learning_rate: 0.0010
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7949 - loss: 0.4209 - val_accuracy: 0.7625 - val_loss: 0.5328 - learning_rate: 0.0010
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7855 - loss: 0.4397 - val_accuracy: 0.7638 - val_loss: 0.5170 - learning_rate: 0.0010
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7779 - loss: 0.4347 - val_accuracy: 0.7625 - val_loss: 0.5535 - learning_rate: 0.0010
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7876 - loss: 0.4286 - val_accuracy: 0.7525 - val_loss: 0.5661 - learning_rate: 0.0010
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7900 - loss: 0.4378 - val_accuracy: 0.7638 - val_loss: 0.5277 - learning_rate: 0.0010
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7771 - loss: 0.4404 - val_accuracy: 0.7275 - val_loss: 0.6022 - learning_rate: 0.0010
# Epoch 24/50
# 46/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7716 - loss: 0.4535
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4472 - val_accuracy: 0.7625 - val_loss: 0.5261 - learning_rate: 0.0010
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7830 - loss: 0.4362 - val_accuracy: 0.7638 - val_loss: 0.5190 - learning_rate: 1.0000e-04
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8019 - loss: 0.4319 - val_accuracy: 0.7638 - val_loss: 0.5188 - learning_rate: 1.0000e-04
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7887 - loss: 0.4222 - val_accuracy: 0.7638 - val_loss: 0.5221 - learning_rate: 1.0000e-04
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7811 - loss: 0.4440 - val_accuracy: 0.7638 - val_loss: 0.5256 - learning_rate: 1.0000e-04
# Epoch 29/50
# 48/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7936 - loss: 0.4087
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7926 - loss: 0.4123 - val_accuracy: 0.7638 - val_loss: 0.5253 - learning_rate: 1.0000e-04
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8069 - loss: 0.4009 - val_accuracy: 0.7638 - val_loss: 0.5253 - learning_rate: 1.0000e-05
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7742 - loss: 0.4298 - val_accuracy: 0.7638 - val_loss: 0.5245 - learning_rate: 1.0000e-05
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7882 - loss: 0.4253 - val_accuracy: 0.7638 - val_loss: 0.5248 - learning_rate: 1.0000e-05
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7934 - loss: 0.4150 - val_accuracy: 0.7638 - val_loss: 0.5248 - learning_rate: 1.0000e-05
# Epoch 34/50
# 40/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8005 - loss: 0.4094
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7983 - loss: 0.4177 - val_accuracy: 0.7638 - val_loss: 0.5251 - learning_rate: 1.0000e-05
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7897 - loss: 0.4380 - val_accuracy: 0.7638 - val_loss: 0.5251 - learning_rate: 1.0000e-06
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7861 - loss: 0.4276 - val_accuracy: 0.7638 - val_loss: 0.5252 - learning_rate: 1.0000e-06
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7960 - loss: 0.4193 - val_accuracy: 0.7638 - val_loss: 0.5251 - learning_rate: 1.0000e-06
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7924 - loss: 0.4319 - val_accuracy: 0.7638 - val_loss: 0.5251 - learning_rate: 1.0000e-06
# Epoch 39/50
# 33/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7625 - loss: 0.4663
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-06.
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7785 - loss: 0.4447 - val_accuracy: 0.7638 - val_loss: 0.5251 - learning_rate: 1.0000e-06
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8038 - loss: 0.4203 - val_accuracy: 0.7638 - val_loss: 0.5253 - learning_rate: 1.0000e-06
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7987 - loss: 0.4220 - val_accuracy: 0.7638 - val_loss: 0.5253 - learning_rate: 1.0000e-06
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.4351 - val_accuracy: 0.7638 - val_loss: 0.5254 - learning_rate: 1.0000e-06
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7910 - loss: 0.4318 - val_accuracy: 0.7638 - val_loss: 0.5255 - learning_rate: 1.0000e-06
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7841 - loss: 0.4390 - val_accuracy: 0.7638 - val_loss: 0.5255 - learning_rate: 1.0000e-06
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7955 - loss: 0.4361 - val_accuracy: 0.7638 - val_loss: 0.5255 - learning_rate: 1.0000e-06
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7914 - loss: 0.4229 - val_accuracy: 0.7638 - val_loss: 0.5255 - learning_rate: 1.0000e-06
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7776 - loss: 0.4259 - val_accuracy: 0.7638 - val_loss: 0.5256 - learning_rate: 1.0000e-06
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7814 - loss: 0.4175 - val_accuracy: 0.7638 - val_loss: 0.5256 - learning_rate: 1.0000e-06
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.4365 - val_accuracy: 0.7638 - val_loss: 0.5256 - learning_rate: 1.0000e-06
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8062 - loss: 0.4090 - val_accuracy: 0.7638 - val_loss: 0.5256 - learning_rate: 1.0000e-06
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Modelo 24 se acabo de entrenar y se guardo

# %%
def mostrar_configuracion(configuracion):
    salida = []
    salida.append("Capas Ocultas:")
    for i, capa in enumerate(configuracion["capas_ocultas"]):
        salida.append(f"  Capa {i + 1}: {capa['neuronas']} neuronas, activación='{capa['activation']}', dropout={capa.get('dropout', 0)}")
    salida.append(f"Learning Rate: {configuracion['learning_rate']}")
    salida.append(f"Factor de Reducción: {configuracion['factor_reduccion']}")
    salida.append(f"Salida: {configuracion['output']['neuronas']} neuronas, activación='{configuracion['output']['activation']}'")
    return "\n".join(salida)

def mostrar_todo_dataframe(df, labels):
    for index, fila in df.iterrows():
        print(f"Modelo {index + 1}:")
        print("-" * 40)
        
        print("Configuración del modelo:")
        print(mostrar_configuracion(fila["configuracion"]))
        
        print("\nMétricas del modelo:")
        print(f"Precisión: {fila['precision']:.4f}")
        print(f"Recall: {fila['recall']:.4f}")
        
        historial = fila["historial"]
        print("\nGraficando historial de entrenamiento...")
        plt.plot(historial["accuracy"], label="Precisión - Entrenamiento")
        plt.plot(historial["val_accuracy"], label="Precisión - Validación")
        plt.title(f"Historial de Precisión - Modelo {index + 1}")
        plt.xlabel("Épocas")
        plt.ylabel("Precisión")
        plt.legend()
        plt.show()

        plt.plot(historial["loss"], label="Pérdida - Entrenamiento")
        plt.plot(historial["val_loss"], label="Pérdida - Validación")
        plt.title(f"Historial de Pérdida - Modelo {index + 1}")
        plt.xlabel("Épocas")
        plt.ylabel("Pérdida")
        plt.legend()
        plt.show()

        print("\nMatriz de Confusión:")
        cm_display = ConfusionMatrixDisplay(fila["matriz_confusion"], display_labels=labels)
        cm_display.plot()
        plt.show()

        print("\n" + "=" * 50 + "\n")

mostrar_todo_dataframe(df_resultados, labels=labels)
# Out:
# Modelo 1:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 32 neuronas, activación='relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 2:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 32 neuronas, activación='tanh', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 3:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 32 neuronas, activación='leaky_relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 4:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 32 neuronas, activación='swish', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 5:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 6:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='tanh', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 7:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='leaky_relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 8:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='swish', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8764
# Recall: 0.7625
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 9:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 10:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='tanh', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 11:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='leaky_relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 12:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='swish', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8747
# Recall: 0.7488
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 13:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='relu', dropout=0.2
#   Capa 2: 64 neuronas, activación='relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 14:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='leaky_relu', dropout=0.2
#   Capa 2: 64 neuronas, activación='leaky_relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 15:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='swish', dropout=0.2
#   Capa 2: 64 neuronas, activación='swish', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 16:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='relu', dropout=0.2
#   Capa 2: 32 neuronas, activación='relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 17:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='leaky_relu', dropout=0.2
#   Capa 2: 32 neuronas, activación='leaky_relu', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 18:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='swish', dropout=0.2
#   Capa 2: 32 neuronas, activación='swish', dropout=0.2
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 19:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='relu', dropout=0.2
#   Capa 2: 64 neuronas, activación='relu', dropout=0.15
#   Capa 3: 32 neuronas, activación='relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 20:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='leaky_relu', dropout=0.2
#   Capa 2: 64 neuronas, activación='leaky_relu', dropout=0.15
#   Capa 3: 32 neuronas, activación='leaky_relu', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 21:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 128 neuronas, activación='swish', dropout=0.2
#   Capa 2: 64 neuronas, activación='swish', dropout=0.15
#   Capa 3: 32 neuronas, activación='swish', dropout=0.1
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 22:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='relu', dropout=0.15
#   Capa 2: 32 neuronas, activación='relu', dropout=0.1
#   Capa 3: 16 neuronas, activación='relu', dropout=0.05
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8723
# Recall: 0.7600
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 23:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='leaky_relu', dropout=0.15
#   Capa 2: 32 neuronas, activación='leaky_relu', dropout=0.1
#   Capa 3: 16 neuronas, activación='leaky_relu', dropout=0.05
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8764
# Recall: 0.7625
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
#
# Modelo 24:
# ----------------------------------------
# Configuración del modelo:
# Capas Ocultas:
#   Capa 1: 64 neuronas, activación='swish', dropout=0.15
#   Capa 2: 32 neuronas, activación='swish', dropout=0.1
#   Capa 3: 16 neuronas, activación='swish', dropout=0.05
# Learning Rate: 0.001
# Factor de Reducción: 0.1
# Salida: 4 neuronas, activación='softmax'
#
# Métricas del modelo:
# Precisión: 0.8785
# Recall: 0.7638
#
# Graficando historial de entrenamiento...
# Matriz de Confusión:
# ==================================================
